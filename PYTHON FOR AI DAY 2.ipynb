# %% [markdown]
# # PYTHON PROGRAMMING LANGUAGE
# ![image.png](attachment:19d0b655-ac4d-4bdf-b27c-48f68b19181b.png)

# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %%
2+3
# Out:
# 5

# %%
_+3 # underscore not accepted because of system version error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 _+3
#
# TypeError: can only concatenate str (not "int") to str

# %%
10-5
# Out:
# 5

# %%
10//5
# Out:
# 2

# %%
10+5-5*(3*2)/3
# Out:
# 5.0

# %%
10%5
# Out:
# 0

# %%
3**2
# Out:
# 9
